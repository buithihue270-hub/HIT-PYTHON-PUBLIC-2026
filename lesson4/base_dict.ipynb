# %% [markdown]
# # Dictionary

# %% [markdown]
# Từ điển được sử dụng để lưu trữ các giá trị trong các cặp `key:value`
#
# Từ điển là một tập hợp được sắp xếp có thứ tự, có thể thay đổi và không cho phép trùng lặp
#
# Từ điển không cho phép có 2 mục cùng 1 khóa

# %%
student = {
    "name": "Nguyen Van A",
    "age": 19,
    "gpa": 8.5
}

print(student)
# Out:
# {'name': 'Nguyen Van A', 'age': 19, 'gpa': 8.5}

# %% [markdown]
# ## Truy cập các mục

# %%
student = {
    "name": "Nguyen Van A",
    "age": 19,
    "gpa": 8.5
}

print(student["name"])
# Out:
# Nguyen Van A

# %%
# Sử dụng get() để lấy giá trị
student.get("name")
# Out:
# 'Nguyen Van A'

# %% [markdown]
# ## Thay đổi giá trị

# %%
student["name"] = "Trần Thị B"

print(student)
# Out:
# {'name': 'Trần Thị B', 'age': 19, 'gpa': 8.5}

# %%
# Sử dụng phương thức update()
student2 = {
    "name": "Lê Văn C",
    "age": 20,
    "gpa": 8.5
}

student.update({"name": "Nguyễn Hà My", "gpa": 9.0})
print(student)
# Out:
# {'name': 'Nguyễn Hà My', 'age': 19, 'gpa': 9.0}

# %% [markdown]
# ## Thêm các mục

# %%
student["yob"] = 2007 # Keyword mới
print(student)
# Out:
# {'name': 'Nguyễn Hà My', 'age': 19, 'gpa': 9.0, 'yob': 2007}

# %%
student.update({"hometown": "Hà Nội"})
print(student)
# Out:
# {'name': 'Nguyễn Hà My', 'age': 19, 'gpa': 9.0, 'yob': 2007, 'hometown': 'Hà Nội'}

# %% [markdown]
# ***Chú ý:*** Cú pháp giống thêm một giá trị mới, tuy nhiên khóa phải chưa tồn tại trong dictionary ban đầu

# %% [markdown]
# ## Loại bỏ các mục

# %%
# Phương thức pop()
student.pop("hometown") #pop: trả về giá trị xoá
print(student)
# Out:
# {'name': 'Nguyễn Hà My', 'age': 19, 'gpa': 9.0, 'yob': 2007}

# %%
a = student.pop("hometown")
print(a)
print(student)

# %%
# Phương thức popitem()
student.popitem()
print(student)
# Out:
# {'name': 'Nguyễn Hà My', 'age': 19, 'gpa': 9.0}

# %%
# Từ khóa del xóa cặp key:value được chỉ định
del student["gpa"]
print(student)

# Từ khóa del dùng để xóa toàn bộ dict
del student
print(student)

# %%
# Từ khóa clear để xóa toàn dict
student = {
    "name": "Nguyen Van A",
    "age": 19,
    "gpa": 8.5
}
print(student)
student.clear()
print(student)

# %% [markdown]
# ## Duyệt dict bằng vòng lặp

# %%
student = {
    "name": "Nguyen Van A",
    "age": 19,
    "gpa": 8.5
}

# In các khóa có trong từ điển
for x in student:
    print(x)
value_1 = []
# Duyệt các giá trị
for value in student.values():
    value_1.append(value)
    print(value_1)
key_1 =[]
# Duyệt các khóa
for key in student.keys():
    key_1.append(key)
    print(key_1)

# Duyệt các cặp khóa - giá trị
for key, value in student.items():
    print(key, value)
# Out:
# name
# age
# gpa
# ['Nguyen Van A']
# ['Nguyen Van A', 19]
# ['Nguyen Van A', 19, 8.5]
# ['name']
# ['name', 'age']
# ['name', 'age', 'gpa']
# name Nguyen Van A
# age 19
# gpa 8.5

# %% [markdown]
# # Bài tập 1
#
# Xây dựng một từ điển, có các chức năng như sau: (người dùng thực hiện chức năng thông qua menu):
# 1. Thêm một từ vựng mới kèm nghĩa của từ vào từ điển
# 2. Tra cứu ý nghĩa của 1 từ vựng
# 3. Cập nhật ý nghĩa cho một từ vựng
# 4. Cho phép người dùng xóa đi một từ vựng trong từ điển
# 5. Cho phép người dùng xóa toàn bộ từ vựng
# 6. Cho phép người dùng in ra toàn bộ từ vựng
# 7. Cho phép người dùng in ra toàn bộ từ điển theo cấu trúc: "TỪ VỰNG" : "Ý NGHĨA"
# 8. Kết thúc chương trình
#
# **Yêu cầu:** Hiển thị thông báo yêu cầu người dùng chọn chức năng, nhập thông tin cần thiết (từ vựng mới, từ vựng cần tìm, từ vựng cần sửa, từ vựng cần xóa)

# %% [markdown]
# **Gợi ý:**
#
# ```
# dictionary = {}
#
# while True:
#     print("Vui long lua chon chuc nang: ")
#     print("""
#         1. Thêm một từ vựng mới kèm nghĩa của từ vào từ điển
#         2. Tra cứu ý nghĩa của 1 từ vựng
#         3. Cập nhật ý nghĩa cho một từ vựng
#         4. Cho phép người dùng xóa đi một từ vựng trong từ điển
#         5. Cho phép người dùng xóa toàn bộ từ vựng
#         6. Cho phép người dùng in ra toàn bộ từ vựng
#         7. Cho phép người dùng in ra toàn bộ từ điển theo cấu trúc: "TỪ VỰNG" : "Ý NGHĨA"
#         8. Kết thúc chương trình
#     """)
#
#     choice = int(input("Nhập vào lựa chọn của bạn: "))
#     if choice == 1:
#         pass
#     elif choice == 2:
#         pass
#     elif choice == 3:
#         pass
#     elif choice == 4:
#         pass
#     elif choice == 5:
#         pass
#     elif choice == 6:
#         pass
#     elif choice == 7:
#         pass
#     elif choice == 8:
#         break
#     else:
#         print("Lựa chọn không hợp lệ!")
# ```
